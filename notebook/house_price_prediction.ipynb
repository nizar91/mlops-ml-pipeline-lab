# %% [markdown]
# ## 1 - data preprocessing
#
# Explorative data analysis

# %%
import pandas as pd
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Define the file path to raw data housing.csv
filepath = ## your code here

# Read the CSV file into a DataFrame
df = pd.read_csv(filepath)

# %%
# Display the first 5 rows of the DataFrame using `head` method
## your code here`

# %%
 # Display the last 5 rows of the DataFrame using `tail` method
## your code here

# %%
# Display a concise summary of a DataFrame using `info` method
## your code here

# %%
# Check for duplicate rows in the DataFrame using `duplicated` and `sum` method
## your code here

# %%
# Check for missing values in each column using `isnull` and `sum` method
## your code here

# %%
# strip whitespace from column names using `str.strip` method

df.columns = ## your code here

# %% [markdown]
# ## 2 - Split data
# split data into train and test data

# %%
#  Split data into train, test using `train_test_split` with this paramaters: test_size=0.2, random_state=42, shuffle=True
df_train, df_test = ## your code here

# %%
# check train data
df_train.head()

# %%
# check test data
df_test.head()

# %%
df_train.columns

# %% [markdown]
# ## 3 - train ml model

# %%
# price houses
target_column = "MEDV"

# %%
# get features for train
X_train = df_train.drop([target_column], axis=1)

X_train.head()

# %%
# get target for train data
Y_train = df_train[target_column]

Y_train.head()

# %%
# get feature for test data
X_test=## your code here

# %%
# get target for test data
Y_test=## your code here

# %%
# Create linear regression object
model = LinearRegression()

# Train the model using the training sets
## your code here

# %%
# Predict the values using the model on train data
train_predictions = model.predict(X_train)


# evaluate model on train data
print("Mean Squared Error on train data: \n")
mean_squared_error(Y_train, train_predictions)

# %%
# Predict the values using the model on test data
test_predictions = ## your code here

# evaluate model on test data
print("Mean Squared Error on test data: \n")
## your code here))
